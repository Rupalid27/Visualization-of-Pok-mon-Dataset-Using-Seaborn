# %%
import seaborn as sns

# %%
import pandas as pd
pokemon_df  = pd.read_csv("pokemon.csv")
pokemon_df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
pokemon_df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
pokemon_df.isna().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2       84
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Stage         0
# Legendary     0
# dtype: int64

# %%
pokemon_df.iloc[:,[3]]
# Out:
#      Type 2
# 0    Poison
# 1    Poison
# 2    Poison
# 3       NaN
# 4       NaN
# ..      ...
# 146     NaN
# 147     NaN
# 148  Flying
# 149     NaN
# 150     NaN
#
# [151 rows x 1 columns]

# %%
pokemon_df1 = pokemon_df.dropna()
pokemon_df1.shape
# Out:
# (67, 13)

# %%
pokemon_df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
pokemon_df.dropna(inplace = True)
pokemon_df.shape
# Out:
# (67, 13)

# %%
import matplotlib.pyplot as plt
sns.displot(pokemon_df.iloc[:,[5]])
plt.show()

# %%
## Seaborn's Plotting Function

# %%
sns.lmplot (x = "Attack", y = "Defense", data = pokemon_df)
plt.show()

# %%
sns.lmplot (x = "Attack", y = "Defense", data = pokemon_df,
           fit_reg = False, ## No regression Line
           hue = "Stage")  ## Color by evaluation stage
plt.show()

# %%
sns.lmplot (x = "Attack", y = "Defense", data = pokemon_df,
           fit_reg = False, ## No regression Line
           hue = "Stage")  ## Color by evaluation stage

# Tweak using matplotlib

plt.ylim(0,150) ## lim - Limit to y axis
plt.xlim(0,123)

plt.show()

# %%
#sns
sns.boxplot(data = pokemon_df.iloc[:,[5]])
plt.show()

# %%
pokemon_df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
#pre-format DataFrame
stats_df = pokemon_df.drop(["#",'Total','Stage', 'Legendary'], axis = 1)

# New boxplot using stats_df
sns.boxplot(data = stats_df)
plt.show()

# %%
# set theme
sns.set_style("darkgrid")

# Violin plot
plt.figure(figsize = (10,5))
sns.violinplot( x = "Type 1", y = "Attack", data = pokemon_df)
plt.show()

# %%
# Swarn plot with Pokemon color palette
plt.figure(figsize = (10,4))
sns.swarmplot(x = "Type 1", y = "Attack", data =  pokemon_df)
plt.show()

# %%
# set figure size

plt.figure(figsize=(10,6))

# Create Plot
# Plot 1
sns.violinplot( x = "Type 1", 
               y = "Attack", 
               data = pokemon_df, 
               inner = None) # Inner None -> Remove the bars inside the Violins

#Plot 2 
sns.swarmplot(x = "Type 1", y = "Attack", 
              data =  pokemon_df, 
              color = "k", # Make points Black
              alpha = 0.3) # and slightle transparent

# set title with Matplotlib
plt.title("Attack by Type") 
plt.show()

# %%
# heatmap helps you visualise matrix like data
# calculated Correlation
corr = stats_df.corr()
#print(corr)

#heatmap
sns.heatmap(corr, cmap = "YlGnBu", annot = True) # Annot -> Label
plt.show()

# %%
plt.figure(figsize =  (10,5))

#count plot (a.k.a  Bar plot)
sns.countplot(x = "Type 1", data = pokemon_df)
# sns.countplot(y = "Type 1", data = pokemon_df)

#rotate x-label
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize =  (10,5))

#count plot (a.k.a  Bar plot)
#sns.countplot(x = "Type 1", data = pokemon_df)
sns.countplot(y = "Type 1", data = pokemon_df)

#rotate x-label
plt.xticks(rotation = 1)
plt.show()

# %%
sns.countplot(x = "Legendary", data = pokemon_df)
plt.show()

# %%
# Pointplot
sns.pointplot(data = pokemon_df, x = "Stage", y = "Attack")
plt.show()

# %%
## Kernel density estimation Plot

sns.displot(x = "Attack", y = "Defense",kind = "kde", data = pokemon_df, height = 7) # Kind = Type of plot
plt.show()

# %%
#import  titanic dataset from seaborn --> Preimported dataset
titanic  = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(x = "survived", data =  titanic)
plt.show()
